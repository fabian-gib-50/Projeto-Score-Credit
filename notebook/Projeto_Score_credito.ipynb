# %% [markdown]
# <center><img alt='Dbian Data Scientist' width="100%" src=https://user-images.githubusercontent.com/79420053/193087606-c74d7cdc-f5a2-4900-ba2e-c06108d1b586.png></center>

# %% [markdown]
# ___
# ## <center><strong> <em>PROJETO DE DATA SCIENTIST COM MACHINE LEARNING - IA<em> <strong></center>
#
# - **PROJETO SOBRE SCORE DE CLIENTES E LINHAS DE CRÉDITO**
#
#    - O score de crédito é o resultado dos hábitos de pagamento e relacionamento do cidadão com o mercado de crédito. O Serasa Score está disponível para consulta online, permitindo que somente o próprio consumidor veja a sua pontuação.
#
#    - Essa informação vai ajudar o consumidor a ter mais controle da sua vida financeira. Mas você sabe o que é Score de crédito?
#
#    - Desde abril, todos os brasileiros já podem conhecer gratuitamente seu Serasa Score, pontuação que resulta do relacionamento do consumidor com o mercado. O score está disponível na internet e vai de 0 a 1.000 pontos. Cada usuário é pontuado de acordo com a análise de uma série de fatores, como:
#
# * Pagamentos de contas em dia
# * Histórico de dívidas negativadas
# * Relacionamento financeiro com empresas
# * Dados cadastrais atualizados.

# %% [markdown]
# ___
# ### <strong><em><span style='background-color:lightblue'>Dbian Technology and Data Science for Business<em><strong>
#
#    - by [Dbian.io Data Scientist](https://www.linkedin.com/company/81834844/admin/)
# ___

# %% [markdown]
# ### <center><strong> <em> <span style='background-color:lightyellow'>ESCOPO DO PROJETO<em> <strong></center><span style>
# ---
#   - **ENTENDIMENTO DO PROBLEMA DE NEGÓCIO**
# ---
#   - Prever o Score dos Clientes:
#      - A ideia é reunir subsidios com base nos dados dos clientes para prever o Score, pontuação de cada cliente e usá-los para predições de liberação de crédito.
#
#      - Farei análise exploratória e gerarei métricas com indicadores para cenarizar diversas possíbilidades e estratégias que poderão ser adotadas.
#      - Meu objetivo será avaliar quais atributos contribuem e ( influênciam ) nas tomadas de decisões sobre a construção de Score e Liberação de Crédito. Quais atributos mais contribuem para simulações de créditos e consequentemente somam para o Score de Crédito Positivo.

# %% [markdown]
# #### EMPRESA: <em>`SEBRASA SCORE CREDIT`<em>
#
#   -  Nesse projeto aplicarei inúmeras técnicas, inclusive `Machine Learning` com ( IA ).
#    - <em>`Predições` com **Machine Learning**: Métricas e Análise Estatística, gerando `indicadores` e comparativos para melhor `cenarizar`.
#    - Adotarei modelos de **Classificação Linear** porque para esse projeto será mais assertivo.

# %% [markdown]
#  ---
#  <strong>Linguagem de programação principal <em>`PYTHON` & `Livros` de apoio aos projetos e metodologias. <em><strong></center>
#   - Linguagem de programação nativa `PYTHON`
#   - Python: https://www.python.org/
#   - Anaconda: https://anaconda.org/
#   - Machine Learning: https://scikit-learn.org/stable/index.html
#   - HTML
#   - IDEs de desenvolvimento: `Anaconda`-`Jupyter-lab` e `VsCode`
#     - Data Scientist para Negócios
#     - Python Data Scientist Handbook
#     - Usarei formatação de fontes em HTML na IDE `Jupyter Lab`
# ---

# %% [markdown]
# #### PIPELINE DO PLANO DE TRABALHO
#
# - 1. Preparação dos Dados
# - 2. 2.1. Processamento de dados missing
# - 2.2. Processamento de Outliers ( valores acima da curva )
# - 2.3. OneHotEncoder
#   - Análises Dados Exploratória (EDA)
# - 3.1. Processamento das variáveis
# - 3.2. Análise Univariada
# - 3.3. Análise Bivariada e Multiviada
# - 3.4. Validação de Hipóteses com códido
#
#   - Processamento dos Dados
# - 4.1. Engineering, Eng. de Features, criação de Variáveis
# - 4.2. Separação dos dados Splitting
# - 4.3. Escalonamento de Features - padronização/normalização
#
#    - Machine Learning Modelos ( implementações )
# - 5.1 Modelagem do Dataset para ML
# - 5.2 Tecnica Smote para balanceamento dos dados
#
#    - Conclusão dos Trabalhos
# - 6.1 Impacto nos negóciso da empresa (faturamento)
#
#
#
#
# ---
# * <strong> Aplicação de Machine Learning - IA<strong>
#   - Modelo de Regressão Linear com Random Forest
#   - Quatro modelos
#   - Dispersão Previsto X Real
#   - Analise do trafego no site
#   - Tranformação de mínimo e máximo
#   - StandardScaler para padronizar dados
#   - Reduzindo Variaveis
#   - Passando para np.log1p para normalização dos dados numéricos
#   - Histogramas
#   - Dispersão
#   - Predições
#   - Dispersão Previsto X Real
#   - Relatório dos modelos e parâmetros que melhor perfomaram

# %% [markdown]
# ### Dicionário de variáveis atributos
#
#   - As análises e construção do modelo preditivo, terão como alvo a variável `Score e Empréstimo`.

# %% [markdown]
# ### Descritivo das variáveis <em>**Score Credit**<em>
#
#   - **Cód. Cliente**: ID identificação do Cliente na base de dados, em algum momento farei à exclusão dessa variável, para esse trabalho não será usada.
#   - **UF**: identifica o estado de origem do cliente;
#   - **Idade**: faixa etária idade dos clientes do conjunto de dados
#   - **Escolaridade**: estudando, se superior e se concluído.
#   - **Esado Civil**: se casado, não casado, divorviado ou viúvo ;
#   - **Qt. de filhos**: se têm filhos, quantos ou se não tem
#   - **Casa própria**: casa é própria ou alugada;
#   - **Qt. Imóveis**: se têm imóveis e quantos têm;
#   - **Valor dos Impveis**: valor médio dos imóveis informados
#   - **Outra renda**: se tem outra renda e o valor;
#   - **Tempo ùltimo Emprego**: qual foi o tempo que o cliente permaneceu no último emprego;
#   - **Trabahando Atualmente**: está trabalhando ou não está trabalhando;
#   - **Último Salário**: valor do último salário;
#   - **Qt. Carros**: se têm carros ou não e se têm quantos têm;
#   - **Score**: pontuação gerada com base nas informações coletadas sobre os clientes;
#
#   - Obs.: O Score é construído, como tido no ínício do projeto, utilizando n\ variáveis para a sua composição. São vários atributos que pesam para a construção do Score Credit.
#
# ---

# %% [markdown]
# ### <em><span style='background-color:lightwhite'>Bibliotecas Python Aplicadas nesse projeto<em>

# %%
# Importação das Bibliotecas comuns

"""Claudio Fabian Stychnicki
   Data Scientist
"""

import pyforest 
import time
import math
import warnings
import pydotplus
import numpy as np
import seaborn as sns
import matplotlib as mpl
import scikitplot as skplt
import scipy.stats as stats
import ipywidgets as widgets
import matplotlib.pyplot as plt
# %matplotlib inline

# Bibliotecas de Marchine Learning 

from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from imblearn import under_sampling, over_sampling
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import MinMaxScaler 
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import GridSearchCV 
from sklearn.tree import export_graphviz
from sklearn.metrics import mean_absolute_error
from sklearn import model_selection as ms
from sklearn import metrics         as m
from sklearn.metrics import r2_score
from sklearn import linear_model 
from collections import Counter
from IPython.display import display, HTML
from IPython.display import Image
from sklearn.metrics import r2_score


# Comando para consultar lista dos parâmetros "rcParams". Fontes e familias das fontes para gráficos e etc...plt.rcParams

mpl.rcParams[ 'axes.spines.left' ]   = ( False )
mpl.rcParams[ 'axes.spines.right' ]  = ( False )
mpl.rcParams[ 'axes.spines.top' ]    = ( False )
mpl.rcParams[ 'axes.spines.bottom' ] = ( False )
mpl.rcParams[ 'axes.grid' ]          = ( False )

#Comando para exibir todas colunas do arquivo

pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)

# Formatando com pd.set_option para exploração dos dados

pd.set_option( 'display.float_format','{:.3f}'.format ) 

# plt.style.use( 'classic' )
mpl.rc('font', family = 'Verdana' )

# Função ignore ara ignorar os avisos de atualizações de bibiliotecas e avisos diversos

if not sys.warnoptions:
    import warnings
    warnings.simplefilter('ignore')
    warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ---
# ## Importando a base de dados da <em>`SEBRASA SCORE CREDIT`<em>

# %%
# Iportando e lendo a base de dados

# file_path = ( 'https://www.dropbox.com/s/ch69238brbvrf56/dados_score_credito.xlsx?raw=1' )
file_path = ( './img/dados_score_credito.xlsx' )         
df_raw = pd.read_excel( file_path ).copy()


# Codigo para checar as dimensões do conjunto de dados e imprimir cinco linhas da base

print( f'Dimensões do Dataset:\n' )
print( f'Base de Dados importada com sucesso!\n' )
print( 'Quantidade de Variáveis ( colunas ):\t {}'.format( df_raw.shape[1] ) )
print( 'Quantidade de Linhas ( Clientes ): \t {}\n'.format( df_raw.shape[0] ) )
print( f'Leitura dás cinco primeiras linhas do conjunto de dados\n' )

df_raw.head( 5 )
# Out:
# Dimensões do Dataset:
#
# Base de Dados importada com sucesso!
#
# Quantidade de Variáveis ( colunas ):	 17
# Quantidade de Linhas ( Clientes ): 	 10476
#
# Leitura dás cinco primeiras linhas do conjunto de dados
#    CODIGO_CLIENTE  UF  IDADE           ESCOLARIDADE ESTADO_CIVIL  ...  \
# 0               1  SP     19      Superior Cursando     Solteiro  ...
# 1               2  MG     23      Superior Completo     Solteiro  ...
# 2               3  SC     25  Segundo Grau Completo       Casado  ...
# 3               4  PR     27      Superior Cursando       Casado  ...
# 4               5  RJ     28      Superior Completo   Divorciado  ...
#
#    TRABALHANDO_ATUALMENTE ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  \
# 0                     Sim           1800          0                    0
# 1                     Não           4800          1                50000
# 2                     Sim           2200          2                30000
# 3                     Não           3900          0                    0
# 4                     Sim            NaN          1                35000
#
#    SCORE
# 0 12.000
# 1 18.000
# 2 23.000
# 3 28.667
# 4 34.167
#
# [5 rows x 17 columns]

# %%
# Chegando o final do dataset para ter certeza que não há sub-totais, totais e etc...

df_raw.tail( 2 )
# Out:
#        CODIGO_CLIENTE  UF  IDADE           ESCOLARIDADE ESTADO_CIVIL  ...  \
# 10474           10475  RJ     48      Superior Completo   Divorciado  ...
# 10475           10476  PR     51  Segundo Grau Completo   Divorciado  ...
#
#        TRABALHANDO_ATUALMENTE ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  \
# 10474                     Sim            NaN          1                35000
# 10475                     Sim           3100          2                40000
#
#        SCORE
# 10474 34.167
# 10475 39.667
#
# [2 rows x 17 columns]

# %% [markdown]
# ## Análise **exploratória** do Conjunto de Dados ( EDA )
#   - Com base na leitura dás últimas 2 linhas, não tenho intercorrência nos dados.

# %% [markdown]
# ### Criação e Aplicação de Funções:
#
#  - Função para descrever melhor as variáveis **"sumarydata"**
#
#    - Checagem de dados `ausentes`, dados nulos ( nan ), representam dados missing e dados duplicados.
#
#  - Função para converter String em Float
#
#    - Check das variáveis dtypes (tipos) distribuição dos valores e nome das variáveis
#
# ---
# ## Pontos que merecem atenção nessa fase inicial de "awareness" `conhecimento`:
#
# * A coluna `costumerID` não agrega nenhuma informação, trata-se de um identificador único para cada cliente. "Identificação na base da operadora".
# * A variável alvo está na coluna `Score`, indicando a faixa de pontuação ( Score ) de por "cliente".

# %%
# Função criada para otimizar leitura das entredas, chegar as variáveis categóricas, numéricas e os tipos das variáveis

print( '\nPython, imprima descritivo do dicionário das variáveis com sumarização detalhada:\n'.center(110) )

def summarycolumns ( df_raw ): 
    """
       fabian@Ds
                """
    summary = pd.DataFrame( df_raw.dtypes, columns=[ 'dtypes' ] )
    summary = summary.reset_index()
    summary[ 'Nome Variáveis' ] = summary['index']
    summary = summary[[ 'Nome Variáveis', 'dtypes' ]]
    summary[ 'Atributo Primário' ]  = df_raw.loc[0].values
    summary[ 'Atributo Secundário' ] = df_raw.loc[1].values
    summary[ 'Valores Únicos' ] = df_raw.nunique().values
    summary[ 'Dados Duplicados' ] = df_raw.duplicated().sum()
    summary[ 'Dados Ausentes' ] = df_raw.isnull().sum().values 
    
    return summary

check = summarycolumns ( df_raw )

check.head( 20 )
# Out:
#
# Python, imprima descritivo do dicionário das variáveis com sumarização detalhada:
#             Nome Variáveis   dtypes  Atributo Primário Atributo Secundário  \
# 0           CODIGO_CLIENTE    int64                  1                   2
# 1                       UF   object                 SP                  MG
# 2                    IDADE    int64                 19                  23
# 3             ESCOLARIDADE   object  Superior Cursando   Superior Completo
# 4             ESTADO_CIVIL   object           Solteiro            Solteiro
# ..                     ...      ...                ...                 ...
# 12  TRABALHANDO_ATUALMENTE   object                Sim                 Não
# 13          ULTIMO_SALARIO   object               1800                4800
# 14               QT_CARROS    int64                  0                   1
# 15     VALOR_TABELA_CARROS    int64                  0               50000
# 16                   SCORE  float64             12.000              18.000
#
#     Valores Únicos  Dados Duplicados  Dados Ausentes
# 0            10476                 0               0
# 1                5                 0               0
# 2               28                 0               0
# 3                3                 0               0
# 4                4                 0               0
# ..             ...               ...             ...
# 12               2                 0               0
# 13              18                 0               2
# 14               3                 0               0
# 15              11                 0               0
# 16              17                 0               0
#
# [17 rows x 7 columns]

# %% [markdown]
# ___
# ### Adotarei alguns procedimentos.
#   - Farei a exlusão da variável Cod. Cliente. Nesse momento não agreda valor ás análises
#   - Checagem dos dados ausentes por variável em percentual e tratamento, preciso ajustar a variável ULTIMO_SALARIO para gerar análises descritivas

# %% [markdown]
# ---
# * Na checagem acima posso ver que tenho ( 8 ) variáveis com ( 14 ) registros de ausência cada.
# - Procedimento que adotarei. Como irei trabalhar com predição, se enxertar com médiana, posso ter métricas e indicadores que não corresponderão ao propósito. Como trabalhaei com Machine Learning, optei por limpar os registros ausentes, excluíndo-os. São poucos registros frente ao volume de dados...12 mil linhas.
# - Analisando os dados acima posso concluir que o perído vai de fevereiro há dezembro com ( 10 ) meses de coleta dos dados do Google Analytics.
# - Vou investigar melhor a variável `ULTIMO_SALARIO`, preciso detalhar melhor às ocorréncias de dados ausentes, os reais motivos e quantitativos.

# %%
# Aplicação de Describe, incluindo as colunas objetc, excluindo count para validar os dados acima com print( )

df_raw.describe( include=object ).drop(['count']).iloc[ :, : ]
# Out:
#           UF       ESCOLARIDADE ESTADO_CIVIL CASA_PROPRIA OUTRA_RENDA  \
# unique     5                  3            4            2           2
# top       RJ  Superior Completo       Casado          Não         Não
# freq    2916               3672         4716         5724        8352
#
#        TRABALHANDO_ATUALMENTE  ULTIMO_SALARIO
# unique                      2              18
# top                       Sim            1800
# freq                     6336             846

# %%
agg_sal = df_raw.groupby( [ 'ULTIMO_SALARIO' ] ).size().reset_index()
agg_sal
# Out:
#    ULTIMO_SALARIO    0
# 0            1800  846
# 1            2200  792
# 2            3100  792
# 3            3900  792
# 4            4500  468
# ..            ...  ...
# 13          15000  522
# 14          17500  522
# 15          18300  522
# 16          22000  468
# 17      SEM DADOS    1
#
# [18 rows x 2 columns]

# %%
# Passando o shape para variável ULTIMO_SALARIO para entender os valores únicos e os ausentes em percentil

df_raw.ULTIMO_SALARIO.value_counts() / df_raw.shape [0] * 100,2
# Out:
# (1800        8.076
#  2200        7.560
#  3900        7.560
#  3100        7.560
#  4800        7.560
#               ...
#  6100        4.983
#  9800        4.467
#  4500        4.467
#  22000       4.467
#  SEM DADOS   0.010
#  Name: ULTIMO_SALARIO, Length: 18, dtype: float64,
#  2)

# %%
# Quantitativo de dados únicos para a variável ULTIMO_SALARIO e dados NaN ( ausentes )

df_raw.ULTIMO_SALARIO.value_counts( dropna=False )
# Out:
# 1800         846
# 2200         792
# 3900         792
# 3100         792
# 4800         792
#             ...
# 9800         468
# 4500         468
# 22000        468
# NaN            2
# SEM DADOS      1
# Name: ULTIMO_SALARIO, Length: 19, dtype: int64

# %%
# Checando a origem para entender as causas dos dados ausentes na variável ULTIMO_SALARIO

df_raw.loc[df_raw[ 'ULTIMO_SALARIO' ] == 'SEM DADOS']
# Out:
#        CODIGO_CLIENTE  UF  IDADE       ESCOLARIDADE ESTADO_CIVIL  ...  \
# 10459           10460  RJ     45  Superior Cursando     Solteiro  ...
#
#        TRABALHANDO_ATUALMENTE ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  \
# 10459                     Sim      SEM DADOS          0                    0
#
#        SCORE
# 10459 45.167
#
# [1 rows x 17 columns]

# %%
# Checando a causa dos dados ausentes na variável ULTIMO_SALARIO sem dados

check = df_raw.loc[df_raw[ 'ULTIMO_SALARIO' ] == 'SEM DADOS']
check.iloc[ :, 10: 21 ]
# Out:
#        OUTRA_RENDA_VALOR  TEMPO_ULTIMO_EMPREGO_MESES TRABALHANDO_ATUALMENTE  \
# 10459               3000                          19                    Sim
#
#       ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  SCORE
# 10459      SEM DADOS          0                    0 45.167

# %% [markdown]
# ___
# * Substituição de valores ausentes por nan.
#   - Aplicação de função para converter "str" em "float64".
#   - Quero gerara algumas métricas objetivando um maior aprofundamento nas variáveis númericas.

# %%
# Farei a substituição da palabra (string) sem valor por dado nulo.

df_raw.replace( 'SEM DADOS',np.nan, inplace = True)

# %%
# Função para aplicar a conversão da coluna "ÚltimoSalário" de ( `String- object' ) para `Float64`

def conversao_str_float ( entrada ):
    """
    Converte um objeto do tipo string em float.

    # Arguments
        entrada: string, string da coluna TotalCharges.

    # Returns
        Valor convertido em float, caso permita a conversão.
        NaN, caso o valor não seja apropriado.
    """
    try:
        return float( entrada )
    except ValueError:
        return np.nan

# %%
# Aplicando conversão na variável 'ULTIMO_SALARIO'

df_raw[ 'ULTIMO_SALARIO' ] = df_raw[ 'ULTIMO_SALARIO' ].apply( conversao_str_float )

# Aplicando método appply com função lambda math.isnan com a média salárial em x: lambda.

# df_raw[ 'ULTIMO_SALARIO' ] = df_raw[ 'ULTIMO_SALARIO' ].apply( lambda x: x [ 'date'].moth if 
#                                                              math.isnan( x [ 'date'] ) else x [ 'date'], axis=1 ) 
df_raw[ 'ULTIMO_SALARIO' ] = df_raw[ 'ULTIMO_SALARIO' ].apply( lambda x: 8286.0 if math.isnan( x ) else x )

# Print média Último Salário

print( '\nUltimo salário média é:\f', df_raw.ULTIMO_SALARIO.mean() )
# Out:
# Ultimo salário média é: 8287.157121038565

# %%
# Checagem para ver se ainda tenho dados ausentes 

print( 'Checando se tenho mais algum dado ausente'), df_raw.isna().sum().reset_index()
# Out:
# Checando se tenho mais algum dado ausente
# (None,
#                       index  0
#  0           CODIGO_CLIENTE  0
#  1                       UF  0
#  2                    IDADE  0
#  3             ESCOLARIDADE  0
#  4             ESTADO_CIVIL  0
#  ..                     ... ..
#  12  TRABALHANDO_ATUALMENTE  0
#  13          ULTIMO_SALARIO  0
#  14               QT_CARROS  0
#  15     VALOR_TABELA_CARROS  0
#  16                   SCORE  0
#
#  [17 rows x 2 columns])

# %% [markdown]
# ___
# ### Engenharia de Atributos variáveis numéricas
#   - Aplicarei uma técnica com vários métodos de análise descritiva.
#     - Descritivos de média, median, mínimo e máximo. Desvios ( std ), inclinações **`Skew`** e distânciamento central **`Kurtosis`**
# ___
# * Aplicação do método <em>**`select_dtypes`** para filtrar às varáveis numéricas e categóricas.
#   - Método por tipos se ( int64, flat64 ).
#   - Quero gerar algumas métricas objetivando um maior aprofundamento nas variáveis númericas, para isso, criei um codigo para compor Skew e Kurtosis, além disso, gerarei às métricas de média, mediana, desvio ( std ), mininmo e máximo.
#
#   - Tendências centrais **( tcd )**, parar saber o quanto a média central está dispersões dos dados. Usarei técnica para uma análise descritiva com medições das tendências centrais dos valores dás variáveis.
#
#  - Método Skew: trata do distãnciamento da média central, o quanto a variál está inclinada positivamente, ou negativamente.
#  - Método curtose: é o quarto momento central dividido pelo quadrado da variância. Se a definição de Fisher for usada, então 3,0 é subtraído do resultado para dar 0,0 para uma distribuição normal.
#
#     - Se o viés for falso, a curtose é calculada usando a estatística k para eliminar o viés proveniente dos estimadores de momento enviesados.

# %%
# Aplicação do filtro atributos por tipo de variável

nun_attributes = df_raw.select_dtypes( include=[ 'int64', 'float64' ] )
cat_attributes = df_raw.select_dtypes( exclude=[ 'int64', 'float64' ] )

# %%
# Aplicação dos métodos numpy para produzir métricas centrais e dispersões da méda central

tcd1 = pd.DataFrame( nun_attributes.apply( np.mean ) ).T 
tcd2 = pd.DataFrame( nun_attributes.apply( np.median ) ).T

# Dimensão - std, min, max, range, skew, kurtosis

dm1 = pd.DataFrame( nun_attributes.apply( np.std )).T 
dm2 = pd.DataFrame( nun_attributes.apply( min )).T 
dm3 = pd.DataFrame( nun_attributes.apply( max )).T 
dm4 = pd.DataFrame( nun_attributes.apply( lambda x: x.max() - x.min())).T 
dm5 = pd.DataFrame( nun_attributes.apply( lambda x: x.skew())).T 
dm6 = pd.DataFrame( nun_attributes.apply( lambda x: x.kurtosis())).T 

# Concatenando as métricas dos Data Frames para gerar um novo DF. 

df_metricas = pd.concat( [ dm2, dm3, dm4, tcd1, tcd2, dm1, dm5, dm6 ] ).T.reset_index() 
df_metricas.columns = [ 'Atributos', 'min', 'max', 'range', 'mean', 'median', 'std', 'centro', 'curtosi' ]

print( 'RELATÓRIO DOS MÉTODOS DESCRITÍVOS SKEW E KURTOSIS'.center( 120 ) )
print( "" )

# Abrindo o Data Frame.
df_metricas.head( 10 )
# Out:
#                                    RELATÓRIO DOS MÉTODOS DESCRITÍVOS SKEW E KURTOSIS
#                     Atributos      min        max      range       mean  \
# 0              CODIGO_CLIENTE    1.000  10476.000  10475.000   5238.500
# 1                       IDADE   19.000     65.000     46.000     41.054
# 2                   QT_FILHOS    0.000     42.000     42.000      1.123
# 3                  QT_IMOVEIS    0.000      3.000      3.000      0.847
# 4                  VL_IMOVEIS    0.000 900000.000 900000.000 238453.608
# 5           OUTRA_RENDA_VALOR    0.000   4000.000   4000.000    641.237
# 6  TEMPO_ULTIMO_EMPREGO_MESES    8.000    150.000    142.000     43.070
# 7              ULTIMO_SALARIO 1800.000  22000.000  20200.000   8287.157
# 8                   QT_CARROS    0.000      2.000      2.000      0.936
# 9         VALOR_TABELA_CARROS    0.000 180000.000 180000.000  40996.564
#
#       median        std  centro  curtosi
# 0   5238.500   3024.161   0.000   -1.200
# 1     42.000     13.877   0.087   -1.289
# 2      1.000      1.113   8.484  286.638
# 3      1.000      0.957   0.991    0.022
# 4 185000.000 265831.246   0.891   -0.132
# 5      0.000   1295.916   1.619    0.847
# 6     22.000     40.850   1.213    0.305
# 7   6100.000   5826.194   0.827   -0.458
# 8      1.000      0.807   0.116   -1.454
# 9  35000.000  47401.951   1.606    2.167

# %%
# Clarificando a variável "alvo" e "Último Salário" com técnica "select_dtypes" para um descritiva

pd.set_option('display.float_format','{:.4f}'.format)  
(
 df_raw
 .select_dtypes(float)
 .describe().drop( [ 'count' ] ).T
)
# Out:
#                     mean       std       min       25%       50%        75%  \
# ULTIMO_SALARIO 8287.1571 5826.4722 1800.0000 3900.0000 6100.0000 11500.0000
# SCORE            51.0587   27.3063   12.0000   28.6667   45.1667    72.6667
#
#                       max
# ULTIMO_SALARIO 22000.0000
# SCORE             98.0000

# %%
# Clarificando ás variáveis numéricas com descritivo sem coluna "count"

(
 df_raw
 .select_dtypes(int)
 .describe().drop( [ 'count' ] ).round(2).T
)
# Out:
#                                   mean         std     min       25%  \
# CODIGO_CLIENTE               5238.5000   3024.3100  1.0000 2619.7500
# IDADE                          41.0500     13.8800 19.0000   28.0000
# QT_FILHOS                       1.1200      1.1100  0.0000    0.0000
# QT_IMOVEIS                      0.8500      0.9600  0.0000    0.0000
# VL_IMOVEIS                 238453.6100 265843.9300  0.0000    0.0000
# OUTRA_RENDA_VALOR             641.2400   1295.9800  0.0000    0.0000
# TEMPO_ULTIMO_EMPREGO_MESES     43.0700     40.8500  8.0000   14.0000
# QT_CARROS                       0.9400      0.8100  0.0000    0.0000
# VALOR_TABELA_CARROS         40996.5600  47404.2100  0.0000    0.0000
#
#                                    50%         75%         max
# CODIGO_CLIENTE               5238.5000   7857.2500  10476.0000
# IDADE                          42.0000     53.0000     65.0000
# QT_FILHOS                       1.0000      2.0000     42.0000
# QT_IMOVEIS                      1.0000      1.0000      3.0000
# VL_IMOVEIS                 185000.0000 370000.0000 900000.0000
# OUTRA_RENDA_VALOR               0.0000      0.0000   4000.0000
# TEMPO_ULTIMO_EMPREGO_MESES     22.0000     75.0000    150.0000
# QT_CARROS                       1.0000      2.0000      2.0000
# VALOR_TABELA_CARROS         35000.0000  50000.0000 180000.0000

# %%
# Análise descritiva com todas ás variáveis int e float

df_raw.describe( ).drop( [ 'count' ] ).round(2)
# Out:
#       CODIGO_CLIENTE   IDADE  QT_FILHOS  QT_IMOVEIS  VL_IMOVEIS  ...  \
# mean       5238.5000 41.0500     1.1200      0.8500 238453.6100  ...
# std        3024.3100 13.8800     1.1100      0.9600 265843.9300  ...
# min           1.0000 19.0000     0.0000      0.0000      0.0000  ...
# 25%        2619.7500 28.0000     0.0000      0.0000      0.0000  ...
# 50%        5238.5000 42.0000     1.0000      1.0000 185000.0000  ...
# 75%        7857.2500 53.0000     2.0000      1.0000 370000.0000  ...
# max       10476.0000 65.0000    42.0000      3.0000 900000.0000  ...
#
#       TEMPO_ULTIMO_EMPREGO_MESES  ULTIMO_SALARIO  QT_CARROS  \
# mean                     43.0700       8287.1600     0.9400
# std                      40.8500       5826.4700     0.8100
# min                       8.0000       1800.0000     0.0000
# 25%                      14.0000       3900.0000     0.0000
# 50%                      22.0000       6100.0000     1.0000
# 75%                      75.0000      11500.0000     2.0000
# max                     150.0000      22000.0000     2.0000
#
#       VALOR_TABELA_CARROS   SCORE
# mean           40996.5600 51.0600
# std            47404.2100 27.3100
# min                0.0000 12.0000
# 25%                0.0000 28.6700
# 50%            35000.0000 45.1700
# 75%            50000.0000 72.6700
# max           180000.0000 98.0000
#
# [7 rows x 11 columns]

# %%
# For para implemntar "boxplots"

var_num = [ ]

for i in df_raw.columns[ 0:16 ].tolist():
           if df_raw.dtypes[ i ] == 'int64' or df_raw.dtypes[i] == 'float64':
              # print( i, ':', df_raw.dtypes[ i ] )
              var_num.append( i )

# %% [markdown]
# ### Criando um filtro "for" para trazer somente variáveis numéricas em boxplot para enteder as distribuições
#    - Com base na var_num criada acima, sigo persquisando e investidando as varáveis numéricas ( Int e Float )

# %%
# Aplicarei n/ gráficos boxplot para entendimento das distribuiões dos intra-quartis ( outliers )

plt.rcParams["figure.figsize"] = [15.00, 12.00]
# plt.rcParams["figure.autolayout"] = True
print( )
print( 'BOXPLOT COM TODAS AS VARIÁVEIS NUMÉRICAS PARA ENTENDER AS DISTRIBUIÇÕES'.center( 160 ) )
print( )
f, axes = plt.subplots( 2, 5 ) 

linha  = 0
coluna = 0

for i in var_num:
    sns.boxplot( data=df_raw, y=i, palette= ["#90F1EF"], ax=axes[linha][coluna] );
    coluna += 1
    if coluna == 5:
        linha += 1
        coluna = 0            

plt.grid(False),
plt.box(True),

plt.tight_layout ();
# Out:
#                                             BOXPLOT COM TODAS AS VARIÁVEIS NUMÉRICAS PARA ENTENDER AS DISTRIBUIÇÕES

# %% [markdown]
# ### Checagem de Outliers: <em>**valores muito acima da média**<em>
#
# * Com base nos boxplots acima têm alguns Outliers nás variáveis: `QT_FILHOS, QT_IMOVEIS, VALOR_TABELA_CARROS e OUTRA_RENDA_VALOR`.
#   - Vou analisar com cautela para entender como tratar esses casos, porque vou trabalhar com essas variáveis.
#
#
# * Farei um filtro para pegar número de filhos acima ( q ) > 4 ( f ).
# * Tenho ( 2 ) registros, aponstando que estão fora da curva. O que fazer?
# * Como são só dois registros e ficou evidente que houve algum equivoco, adotarei o procedimento de limpeza ( exclusão ).
# * Tenho um registro com ( 38 ) e outro com ( 42 ) filhos.
# - Toda via o mesmo não aplica-se a variável QT_IMOVEIS. Por quê? Pelo fato de que temos pessoas que poderão ter vários imóveis, por tanto, não é "outlier". Agora..tudo depende de como ela será usada, para isso, cabe outros procedimentos no caso desta variável tiver "outiliers" muito acima da média.
# - `Por que adotar esse procedimento? Porque caso os deixe, em alguma análise futura esses dois casos poderão distorcer qualquer métrica e ou indicador`.
#
# - Farei alguns agrupamentos na sequência para detalhar melhor as variáveis em análise.

# %%
# Trazendo ambos os registros que estão acima da curva para ver quais são.

df_raw.loc[ df_raw[ 'QT_FILHOS' ] > 4 ]
# Out:
#        CODIGO_CLIENTE  UF  IDADE           ESCOLARIDADE ESTADO_CIVIL  ...  \
# 27                 28  SP     48      Superior Completo   Divorciado  ...
# 10455           10456  SP     45  Segundo Grau Completo       Casado  ...
#
#        TRABALHANDO_ATUALMENTE ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  \
# 27                        Sim     15000.0000          1                70000
# 10455                     Sim      2200.0000          2                30000
#
#         SCORE
# 27    67.1667
# 10455 23.0000
#
# [2 rows x 17 columns]

# %%
# Filtrando e efeturando à exclusão dos registros acima da curva.

df_raw.drop(df_raw.loc[ df_raw[ 'QT_FILHOS' ] > 4 ].index, inplace=True )

# %%
# Agrupamento variável "Outra Renda Valores"

agg_outra_renda_valor = df_raw.groupby( [ 'OUTRA_RENDA_VALOR' ] ).size().reset_index()
agg_outra_renda_valor
# Out:
#    OUTRA_RENDA_VALOR     0
# 0                  0  8350
# 1               2400   468
# 2               3000   612
# 3               3200   522
# 4               4000   522

# %%
# Agrupamento variável "Valores Tabel de Carros"

agg_tab_carros = df_raw.groupby( [ 'VALOR_TABELA_CARROS' ] ).size().reset_index()
agg_tab_carros
# Out:
#     VALOR_TABELA_CARROS     0
# 0                     0  3762
# 1                 28000   468
# 2                 30000   791
# 3                 35000   792
# 4                 40000   792
# ..                  ...   ...
# 6                 50000  1314
# 7                 70000   521
# 8                 80000   522
# 9                150000   468
# 10               180000   522
#
# [11 rows x 2 columns]

# %%
# Agrupamento variável "Qt. Imóveis"

agg_imoveis = df_raw.groupby( [ 'QT_IMOVEIS' ] ).size().reset_index()
agg_imoveis
# Out:
#    QT_IMOVEIS     0
# 0           0  4680
# 1           1  3761
# 2           2   989
# 3           3  1044

# %% [markdown]
# ### Aplicação de n_ gráficos para compreender a distância euclidiana
#
#   - Entender como estão distribuidas as variáveis observando e comparando uma à uma.
#     - Obs.: Há uma certa dispersão entre os dados por variável, e como conseguência entre elas o distândiamento é visível também. Algumas estão bem espaçadas, será preciso normalizar os dados para **Machine Learning**

# %%
# For para gerar graficos das variáveis para ver como estão distribuidas

plt.rcParams[ 'figure.figsize' ] = [15.00, 12.00]
plt.rcParams[ 'figure.autolayout' ] = True

f, axes = plt.subplots(4, 3)

linha  = 0
coluna = 0

for i in var_num:
    sns.histplot(data = df_raw, palette= ["#001D3D"], x=i, ax=axes[linha][coluna])    
    coluna += 1
    if coluna == 3:
        linha += 1
        coluna = 0            

plt.grid(False),
plt.box(False),

plt.tight_layout()

# %%
# Através do hitmap podemos observar a correlação entre todas as variáveis.

plt.rcParams["figure.figsize"] = ( 18, 8 )
ax = sns.heatmap( df_raw.corr(), cmap='coolwarm', annot=True ), 
plt.title( 'MATRIZ DE CORRELAÇÃO ENTRE VARIÁVEIS', pad=25, fontsize=15, color='Black' );

plt.tight_layout()

# %%
# Relatório das variáveis que conrrelacionam-se   

describe = df_raw.corr()[ 'SCORE' ].sort_values(ascending=False).reset_index()
describe
# Out:
#                          index   SCORE
# 0                        SCORE  1.0000
# 1   TEMPO_ULTIMO_EMPREGO_MESES  0.7598
# 2                   VL_IMOVEIS  0.6496
# 3               ULTIMO_SALARIO  0.5962
# 4                   QT_IMOVEIS  0.5793
# ..                         ...     ...
# 6          VALOR_TABELA_CARROS  0.3508
# 7                    QT_FILHOS  0.3346
# 8                        IDADE  0.2198
# 9                    QT_CARROS  0.0644
# 10              CODIGO_CLIENTE -0.0039
#
# [11 rows x 2 columns]

# %% [markdown]
# * Fica evidente que quanto melhor a média por tempo de serviço - emprego, maior é a pontuação "Score"

# %%
# Olhando para à matriz de correlação, vejo uma forte correlação entre Score X "Tempo último emprego meses". Aplicarei um gráfico para entendimento.

sns.lmplot(x = 'TEMPO_ULTIMO_EMPREGO_MESES', y = 'SCORE', data = df_raw );
plt.title( 'CORRELAÇÃO ENTRE ÚLTIMO EMPREGO E O SCORE' )

plt.show()

# %% [markdown]
# * Fica evidente que quanto melhor a média do Valor do Imóvel, melhor à pontuação "Score"

# %% [markdown]
# ### Engenharia de Atributos
#   - Criarei nova variável para segmentar por faixa de idade ( `clusterizar/agrupar` )
#   - Idade mínima, média, máxima e faixa da moda das `idades` que deverá ter um range que inícia em **( 0 ) e possívelmente irá até ( 50 )**, pelo que já ví anteriormente.

# %%
# Criando minímo, médio, máximo e moda de idades dos clientes na base

print( f'\nPython, traga resultado dos parâmetros informados:\n' )
print( f'Quero a menor idade   :\f', df_raw[ 'IDADE' ].min  () )
print( f'Quero a média de idade:\f', df_raw[ 'IDADE' ].mean () )
print( f'Quero a maior idade   :\f', df_raw[ 'IDADE' ].max  () )
print( f'Quero a moda de idade :\f', df_raw[ 'IDADE' ].mode () )
# Out:
# Python, traga resultado dos parâmetros informados:
#
# Quero a menor idade   : 19
# Quero a média de idade: 41.05308382661829
# Quero a maior idade   : 65
# Quero a moda de idade : 0    51
# Name: IDADE, dtype: int64

# %%
# Criação de Atributos faixa etaria ( idades )

class_idade_categ = [ 20, 25, 35, 45, 55, 65 ]

categorizacao_idades = [ 'De 20-25', 'De 25-35', 'De 35-45', 'De 45-55', 'De 55-65' ] 
df_raw[ 'FAIXA_ETARIA' ] = pd.cut(df_raw[ 'IDADE' ], class_idade_categ, labels = categorizacao_idades ) 

df_raw.dropna( inplace = True )
print( '\nCategorização dos clientes por faixa de idade:' )

categorizacao = df_raw[ 'FAIXA_ETARIA' ].value_counts()
categorizacao.head()
# Out:
# Categorização dos clientes por faixa de idade:
# De 25-35    3070
# De 45-55    2663
# De 55-65    1692
# De 35-45    1302
# De 20-25    1189
# Name: FAIXA_ETARIA, dtype: int64

# %%
# Agrupamento pela variável Score

agg_categ_cli_idade = df_raw.groupby( [ 'FAIXA_ETARIA' ] ).mean()[ 'SCORE' ]
agg_categ_cli_idade.head()
# Out:
# FAIXA_ETARIA
# De 20-25   44.2024
# De 25-35   47.9286
# De 35-45   50.1211
# De 45-55   55.2219
# De 55-65   60.1809
# Name: SCORE, dtype: float64

# %%
# Conhecendo o quantitativo das ocorrências de "ESTADO_CIVIL" com Percentil

print( 'Python, imprima quantitativo por faixa de idade em percentual\n' )
df_raw[ 'FAIXA_ETARIA' ].value_counts( normalize=True ).map("{:.2%}".format)
# Out:
# Python, imprima quantitativo por faixa de idade em percentual
# De 25-35    30.96%
# De 45-55    26.86%
# De 55-65    17.06%
# De 35-45    13.13%
# De 20-25    11.99%
# Name: FAIXA_ETARIA, dtype: object

# %% [markdown]
# ### Criação de uma def função para gerar às classificações com label Score.
# - Aplicação e criação de uma nova variável para categoriar os clientes com uma label por faixa de Score
# - Label Score_Credito = `Standard, Good, Poor`
# - Criando outro Data Frame e passando para objeto df_eng, fazendo os processos em blocos.

# %%
# Criando minímo, médio, máximo e moda de Score dos clientes da base

df_eng = df_raw.copy()

print( f'\nPython, traga resultado dos parâmetros informados:\n' )
print( f'Quero o menor Score   :\f', df_eng[ 'SCORE' ].min  () )
print( f'Quero a média Score:\f',    df_eng[ 'SCORE' ].mean () )
print( f'Quero o maior Score   :\f', df_eng[ 'SCORE' ].max  () )
print( f'Quero a moda do Score :\f', df_eng[ 'SCORE' ].mode () )
# Out:
# Python, traga resultado dos parâmetros informados:
#
# Quero o menor Score   : 12.0
# Quero a média Score: 51.81896261934124
# Quero o maior Score   : 98.0
# Quero a moda do Score : 0   18.0000
# 1   34.1667
# Name: SCORE, dtype: float64

# %%
# Função criada para label classificadora Score_Credit

def score_credito_label( SCORE ):
    
    if SCORE < 20:
        return 'Poor' 
    elif SCORE >= 50: 
        return 'Standard' 
    else: 
        return 'Good'

# %%
# Passando a função e criando a nova variável Score_Credit

df_eng [ 'CREDIT_SCORE' ] = df_eng[ 'SCORE' ].apply( score_credito_label )

# Abrindo a nova variável e lendo uma linha

df_eng.head( 3 ).iloc[ :5, 12:21 ]
# Out:
#   TRABALHANDO_ATUALMENTE  ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  \
# 1                    Não       4800.0000          1                50000
# 2                    Sim       2200.0000          2                30000
# 3                    Não       3900.0000          0                    0
#
#     SCORE FAIXA_ETARIA CREDIT_SCORE
# 1 18.0000     De 20-25         Poor
# 2 23.0000     De 20-25         Good
# 3 28.6667     De 25-35         Good

# %%
# Clarificando a variável "alvo" e "Último Salário" com técnica "select_dtypes" para um descritiva

# Conhecendo o quantitativo dos indivíduos com maior tempo de trabalho, sendo superior há 12 meses.

print( 'Python, imprima quantitativo por classificação Score Credito em percentual:\n' )
df_eng[ 'CREDIT_SCORE' ].value_counts( normalize=True ).map("{:.2%}".format)
# Out:
# Python, imprima quantitativo por classificação Score Credito em percentual:
# Standard    49.36%
# Good        36.48%
# Poor        14.16%
# Name: CREDIT_SCORE, dtype: object

# %%
# Aplicação de gráfico de barras para o quantitativo das labels "Standard, Good e Poor"

print( )
fig, ax = plt.subplots( figsize=( 10, 5) )
sns.countplot( x = 'CREDIT_SCORE', palette=sns.color_palette( [ '#CAF0F8', '#0077B6', '#FFBE0B' ] ), data=df_eng, ax=ax )
ax.set_title( 'QUANTITATIVO DE PESSOAS POR CLASSIFICAÇÃO DO SCORE CRÉDITO', pad=35, fontsize=12, color='#001233' )
plt.xticks( [ 0, 1, 2 ], [ 'Poor', 'Good', 'Standard' ], fontsize=12, color='#001233' )

for i in ax.patches:
      ax.annotate(format(round( i.get_height()), '.0f')+"",
                                 (i.get_x() + i.get_width() / 2, 
                                  i.get_height() + 25),
                                  ha='center',
                                  va='baseline',
                                  fontsize= 12,
                                  color='#001233',
                                  fontweight='ultralight',
                                  xytext=(0, 5),
                                  rotation= 0.0,
                                  textcoords='offset pixels'), 

plt.grid( False )
plt.box( False )

plt.tight_layout()

# %% [markdown]
# ### Implementação de uma maximização de ganhos com empréstimos por classificação de score levando em consideração média salárial
#
#   - Esperado: conforme a pontuação e outras varáveis que validarão essa hipótese, o cliente terá seu crédito pessoal ou emprestimos aprovados de imediato.

# %%
# Aplicando agrupamento por identificação do cliente e último salário

df_mean_sal = df_eng[[ 'UF', 'ULTIMO_SALARIO' ]].groupby( 'UF' ).median().reset_index()

df_mean_sal
# Out:
#    UF  ULTIMO_SALARIO
# 0  MG       6100.0000
# 1  PR       4800.0000
# 2  RJ       9800.0000
# 3  SC       5300.0000
# 4  SP       5300.0000

# %%
# Fazendo união dos dados criados com merge 

df_medias = pd.merge( df_eng, df_mean_sal, on='UF', how='inner')

df_medias.head( 5 ).iloc[:, 12:21]
# Out:
#   TRABALHANDO_ATUALMENTE  ULTIMO_SALARIO_x  QT_CARROS  VALOR_TABELA_CARROS  \
# 0                    Não         4800.0000          1                50000
# 1                    Sim         6800.0000          0                    0
# 2                    Não         6100.0000          2                48000
# 3                    Não         4800.0000          1                50000
# 4                    Sim         6800.0000          0                    0
#
#     SCORE FAIXA_ETARIA CREDIT_SCORE  ULTIMO_SALARIO_y
# 0 18.0000     De 20-25         Poor         6100.0000
# 1 45.1667     De 25-35         Good         6100.0000
# 2 72.6667     De 45-55     Standard         6100.0000
# 3 18.0000     De 20-25         Poor         6100.0000
# 4 45.1667     De 25-35         Good         6100.0000

# %%
# Renomeando a coluna ultimo salário e efeturando a exlusão dás colunas ultimo_salario_x e ultimo_salario_y geradas com o merge

cols = ['ULTIMO_SALARIO_x', 'ULTIMO_SALARIO_y']
ren = ['ULTIMO_SALARIO', 'MEDIA_SALARIO_ZIP']
df_medias.rename({cols[0]: ren[0], cols[1]: ren[1]}, axis=1, inplace=True)

# Filtrando somente colunas criadas 

df_medias.head( 1 ).iloc[ :, 15:22 ]
# Out:
#    VALOR_TABELA_CARROS   SCORE FAIXA_ETARIA CREDIT_SCORE  MEDIA_SALARIO_ZIP
# 0                50000 18.0000     De 20-25         Poor          6100.0000

# %%
# Criando uma condição de recomendação para liberar crédito ou não liberar, conforme média salárial e tempo de trabalho

for i in range(len( df_medias )):
    
    if ( df_medias.loc[ i, 'ULTIMO_SALARIO' ] < df_medias.loc[ i, 'MEDIA_SALARIO_ZIP' ] ) & ( df_medias.loc[ i, 'TEMPO_ULTIMO_EMPREGO_MESES' ] > 12 ):
        df_medias.loc[ i, 'RECOMENDADO' ] = 'SIM'
    else:
        df_medias.loc[ i, 'RECOMENDADO' ] = 'NÃO' 

# Filtrando somente colunas criadas  

df_medias.head( 5 ).iloc[ :, 15:22 ]
# Out:
#    VALOR_TABELA_CARROS   SCORE FAIXA_ETARIA CREDIT_SCORE  MEDIA_SALARIO_ZIP  \
# 0                50000 18.0000     De 20-25         Poor          6100.0000
# 1                    0 45.1667     De 25-35         Good          6100.0000
# 2                48000 72.6667     De 45-55     Standard          6100.0000
# 3                50000 18.0000     De 20-25         Poor          6100.0000
# 4                    0 45.1667     De 25-35         Good          6100.0000
#
#   RECOMENDADO
# 0         NÃO
# 1         NÃO
# 2         NÃO
# 3         NÃO
# 4         NÃO

# %%
# Criando uma tabela de recomendações de crédito com todas as variáveis envolvidas

pd.set_option( 'display.float_format','{:.2f}'.format )  

data_report = df_medias[[ 
                          'CODIGO_CLIENTE', 'UF', 'ULTIMO_SALARIO', 'MEDIA_SALARIO_ZIP', 'TEMPO_ULTIMO_EMPREGO_MESES', 'RECOMENDADO' 
                       ]].copy()

# Aplicando uma nova coluna para filtros e identificações 

data_report [ 'VLR_RECOM' ] = data_report [ 'MEDIA_SALARIO_ZIP' ] - data_report [ 'ULTIMO_SALARIO' ]

# Gerando relatório para visualização e to saving

data_report.to_csv('./img/credito_recomendacoes.csv')

# Abrindo e lendo 5 linhas

data_report.tail( 5 )
# Out:
#       CODIGO_CLIENTE  UF  ULTIMO_SALARIO  MEDIA_SALARIO_ZIP  \
# 9911           10451  SP         3900.00            5300.00
# 9912           10461  SP        22000.00            5300.00
# 9913           10465  SP         6100.00            5300.00
# 9914           10469  SP         5300.00            5300.00
# 9915           10473  SP         2200.00            5300.00
#
#       TEMPO_ULTIMO_EMPREGO_MESES RECOMENDADO  VLR_RECOM
# 9911                          22         SIM    1400.00
# 9912                          25         NÃO  -16700.00
# 9913                          80         NÃO    -800.00
# 9914                          93         NÃO       0.00
# 9915                          18         SIM    3100.00

# %%
# Gerando quantitativo de pessos com oportunidade de crédito liberado  

data_report[ 'RECOMENDADO' ].value_counts()
# Out:
# NÃO    6963
# SIM    2953
# Name: RECOMENDADO, dtype: int64

# %%
cred_rec         = data_report.loc[data_report[ 'RECOMENDADO' ] == 'SIM' ]
total_up         = cred_rec ['VLR_RECOM'].sum()
total_cred       = cred_rec ['ULTIMO_SALARIO'].sum()
save_percentagem = total_up  / total_cred * 100
 
print( f'Monta total de crédito em empréstimos consignidos podendo chegar a cerca de: R$ {total_up:.2f} ( {save_percentagem:.2f}% ) caso toda base tivesse \
acesso com menos de 12 meses de empregabilidade, mas assumir-se-ia um enorme risco de inadimplência.' )
# Out:
# Monta total de crédito em empréstimos consignidos podendo chegar a cerca de: R$ 9302642.00 ( 89.73% ) caso toda base tivesse acesso com menos de 12 meses de empregabilidade, mas assumir-se-ia um enorme risco de inadimplência.

# %% [markdown]
# ### Aplicando novos soluções para os clientes com novas régras
#   - Linhas de crédito automáticas usando o APP do Banco

# %%
# Criando um código lambda para uma nova variável class_score "label" clientes.

df_eng[ 'CLASS_SCORE' ] = df_eng[ 'ULTIMO_SALARIO' ].apply( lambda x: 
                                                            'Bom'     if 3500 <= x <= 5500 else
                                                            'Regular' if 5500 <= x <= 7500 else
                                                            'Ótimo'   if 7500 <= x <= 9500 else 
                                                            'Excelente' ) 

# Aplicando dropna para garantir que não terei dados ausentes 

df_eng.dropna(inplace = True)

# %%
# Agrupando dos valores de salários e outra renda por classe_score

dfs_median_renda = df_eng[[ 'ULTIMO_SALARIO', 'OUTRA_RENDA_VALOR', 'CLASS_SCORE']].groupby( [ 'OUTRA_RENDA_VALOR', 'CLASS_SCORE' ] ).median().reset_index()
dfs_median_renda
# Out:
#    OUTRA_RENDA_VALOR CLASS_SCORE  ULTIMO_SALARIO
# 0                  0         Bom         4500.00
# 1                  0   Excelente         9800.00
# 2                  0     Regular         6100.00
# 3                  0       Ótimo         9000.00
# 4               2400   Excelente        22000.00
# 5               3000     Regular         6800.00
# 6               3000       Ótimo         8286.00
# 7               3200         Bom         5300.00
# 8               4000   Excelente        13000.00

# %%
# Renomeando a coluna 'ultimo salário'

dfs_median_renda.rename( {'ULTIMO_SALARIO': 'MEDIAN_RENDA'}, axis=1, inplace=True )

# %%
# Método "merge" para concatenar os valores medianos e unindo-os ao df_eng, aplicando filtro iloc para trazer ás implementações de eng. de atributos

df_result = pd.merge(df_eng, dfs_median_renda, on=['OUTRA_RENDA_VALOR', 'CLASS_SCORE'])

df_result.head(3).iloc[ :, 12:30 ]
# Out:
#   TRABALHANDO_ATUALMENTE  ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  \
# 0                    Não         4800.00          1                50000
# 1                    Não         3900.00          0                    0
# 2                    Sim         4500.00          2                28000
#
#    SCORE FAIXA_ETARIA CREDIT_SCORE CLASS_SCORE  MEDIAN_RENDA
# 0  18.00     De 20-25         Poor         Bom       4500.00
# 1  28.67     De 25-35         Good         Bom       4500.00
# 2  56.17     De 35-45     Standard         Bom       4500.00

# %%
# Criando a coluna para recomendação da melhor média salárial 

for i in range(len( df_result ) ):
    
    if df_result.loc[i, 'ULTIMO_SALARIO'] > df_result.loc[i, 'MEDIAN_RENDA']:
        df_result.loc[i, 'SELL_CRED'] = df_result.loc[i, 'ULTIMO_SALARIO'] * 1.1
    else:
        df_result.loc[i, 'SELL_CRED'] = df_result.loc[i, 'ULTIMO_SALARIO'] * 1.3

# %%
# Adicionando a variável 'profit_score' para apresentar a monta que seria liberada com essa ação

df_result ['PROFIT_CRED'] = df_result['SELL_CRED'] - df_result[ 'ULTIMO_SALARIO' ]

# %%
# Gerando o relatório em arquivo "csv" para o times de negócios trabalharem os clientes. Aplica-se ao time de marketing também.

score_report1 = df_result[[ 
                           'CODIGO_CLIENTE', 'UF', 'CLASS_SCORE', 'IDADE', 'ULTIMO_SALARIO', 'MEDIAN_RENDA', 'SELL_CRED', 'PROFIT_CRED' 
                         ]].copy()
score_report1.to_csv( './img/dados_score_credito.csv' )

score_report1.head( 5 )
# Out:
#    CODIGO_CLIENTE  UF CLASS_SCORE  IDADE  ULTIMO_SALARIO  MEDIAN_RENDA  \
# 0               2  MG         Bom     23         4800.00       4500.00
# 1               4  PR         Bom     27         3900.00       4500.00
# 2               9  PR         Bom     42         4500.00       4500.00
# 3              19  MG         Bom     23         4800.00       4500.00
# 4              21  PR         Bom     27         3900.00       4500.00
#
#    SELL_CRED  PROFIT_CRED
# 0    5280.00       480.00
# 1    5070.00      1170.00
# 2    5850.00      1350.00
# 3    5280.00       480.00
# 4    5070.00      1170.00

# %%
# Checando o valor médio salárial e às possíbilidades de geração de negócios

score_report1[[ 'SELL_CRED', 'ULTIMO_SALARIO' ]].groupby( 'SELL_CRED' ).mean().sort_values( 'ULTIMO_SALARIO', ascending=False ).reset_index()
score_report1.head( 10 )
# Out:
#    CODIGO_CLIENTE  UF CLASS_SCORE  IDADE  ULTIMO_SALARIO  MEDIAN_RENDA  \
# 0               2  MG         Bom     23         4800.00       4500.00
# 1               4  PR         Bom     27         3900.00       4500.00
# 2               9  PR         Bom     42         4500.00       4500.00
# 3              19  MG         Bom     23         4800.00       4500.00
# 4              21  PR         Bom     27         3900.00       4500.00
# 5              26  PR         Bom     42         4500.00       4500.00
# 6              36  MG         Bom     23         4800.00       4500.00
# 7              38  PR         Bom     27         3900.00       4500.00
# 8              43  PR         Bom     42         4500.00       4500.00
# 9              53  MG         Bom     23         4800.00       4500.00
#
#    SELL_CRED  PROFIT_CRED
# 0    5280.00       480.00
# 1    5070.00      1170.00
# 2    5850.00      1350.00
# 3    5280.00       480.00
# 4    5070.00      1170.00
# 5    5850.00      1350.00
# 6    5280.00       480.00
# 7    5070.00      1170.00
# 8    5850.00      1350.00
# 9    5280.00       480.00

# %%
# Gerando uma métrica de apuração para às ações implementadas e o impacto dessa ação sobre o giro mensal de liberação automática de crédito

total_profit = score_report1[ 'PROFIT_CRED' ].sum()
total_price  = score_report1[ 'ULTIMO_SALARIO' ].sum()
percentagem_profit = total_price / total_profit * 100
print( "" )
print( f'A monta que poderia ser acessada pelos clientes corresponde em média a cerca de: R$ {total_profit:.0f} ( {percentagem_profit:.0f}% ) considerando \
a variável profit_cred dividida pelo último salário percebido.')
# Out:
# A monta que poderia ser acessada pelos clientes corresponde em média a cerca de: R$ 17500557 ( 479% ) considerando a variável profit_cred dividida pelo último salário percebido.

# %% [markdown]
# ___
# * Criação de uma variável (target) com classificação para filtros e predições que serão feitas com base em alguns atributos dos indivíduos
#   - Não  - Não aprovado! Critério principale adotado: quando os clientes têm menos de 12 meses de emprego.
#   - Sim  - Aprovado com sucesso!.

# %%
# Criação de uma variável emprestimo com condição se, tempo de trabalho for < q\ 12 recebe não, se > 12 recebe sim.

df_eng[ 'EMPRESTIMO' ] = np.where( df_raw[ 'TEMPO_ULTIMO_EMPREGO_MESES' ] <=12, 'Não', 'Sim' )

# %%
# Agrupamento pela variável Score

agg_analise_emprestimo = df_eng.groupby( [ 'EMPRESTIMO' ] ).mean()[ 'SCORE' ]
agg_analise_emprestimo.head()
# Out:
# EMPRESTIMO
# Não   31.97
# Sim   56.55
# Name: SCORE, dtype: float64

# %%
# Conhecendo o quantitativo dos indivíduos com maior tempo de trabalho, sendo superior há 12 meses.

print( 'Python, imprima quantitativo por tempo de trabalho em percentual\n' )
df_eng[ 'EMPRESTIMO' ].value_counts( normalize=True ).map("{:.2%}".format)
# Out:
# Python, imprima quantitativo por tempo de trabalho em percentual
# Sim    80.76%
# Não    19.24%
# Name: EMPRESTIMO, dtype: object

# %% [markdown]
# ---
# * Quando aplicar tranformação LabelEncoder as tranformações seguirão a seguinte lógica:
#
#   - Não = ( 0 )
#   - Sim = ( 1 )

# %%
# Crosstab dos quantitativos da variável emprestimo X score

dfemp = pd.crosstab(df_eng[ 'EMPRESTIMO' ], df_eng[ 'SCORE' ] )
dfemp.index.name,dfemp.columns.name = ( 'Score:','' )
dfemp.reset_index()
# Out:
#   Score:  12.0  18.0  23.0  28.6666666666667  ...  78.1666666666667  \
# 0    Não   612   792     0                 0  ...               504
# 1    Sim     0     0   773               720  ...                 0
#
#    83.6666666666667  89.1666666666667  94.6666666666667  98.0
# 0                 0                 0                 0     0
# 1               486               504               522   504
#
# [2 rows x 18 columns]

# %%
# Conhecendo o quantitativo das ocorrências de "Churn" com Percentil

print( 'Python, imprima quantitativo de intensões de emprestimo\n' )
display( df_eng[ 'EMPRESTIMO' ].value_counts())
print( )
print( 'Python, imprima quantitativo de intensões de emprestimo em percentual\n' )
display( df_eng[ 'EMPRESTIMO' ].value_counts( normalize=True ).map("{:.2%}".format))
# Out:
# Python, imprima quantitativo de intensões de emprestimo
# Sim    8008
# Não    1908
# Name: EMPRESTIMO, dtype: int64
# Python, imprima quantitativo de intensões de emprestimo em percentual
# Sim    80.76%
# Não    19.24%
# Name: EMPRESTIMO, dtype: object

# %%
# Aplicação de gráfico customizado nova variável agrupada faixa etária e Score

print( )
fig, ax = plt.subplots(figsize=( 15, 5 ) )
agg_analise_emprestimo.plot( kind='bar', color = [ '#80FFDB' ] );
    
plt.xlabel( 'ESCALA EMPREGABILIDADE TEMPO', fontsize= 10, color='#04052E' )
plt.ylabel( 'SCORE - CLIENTES',  fontsize= 10, color='#04052E' )

for i in ax.patches:
      ax.annotate(format( i.get_height(), '.3f')+"",
                                 (i.get_x() + i.get_width() / 2, 
                                  i.get_height() +1 ),
                                  ha='center',
                                  va='baseline',
                                  fontsize= 13,
                                  color='#04052E',
                                  fontweight='ultralight',
                                  xytext=( 0, 1 ),
                                  rotation= 0.0,
                                  textcoords='offset pixels' ), 
plt.text( x= -1.3, 
         y= 40,
         s='$\\bf{NOTAÇÃO}$\n'
         'A maior média\n'
         'está concentrada\n'
         'entre os indivíduos com \n'
         'Score médio bom e emprego\n'
         'superior há 12 meses.',
         verticalalignment="top",
         fontsize=12,
         color='#00072D' ); 

plt.xticks( color='#04052E', 
            fontsize=12, rotation= 0 )

plt.legend()
plt.grid( False )
plt.box( False )
plt.title( 'QUANTITATIVO POR FAIXA DE ADERÊNCIA AO CRÉDITO', 
                        pad=25, fontsize=14, color='#04052E' )

plt.tight_layout()

# %%
# Aplicação de gráfico customizado nova variável agrupada faixa etária e Score

print( )
fig, ax = plt.subplots(figsize=( 15, 5 ) )
agg_categ_cli_idade.plot( kind='bar', color = [ '#1FEAEA' ] );
    
plt.xlabel( 'ESCALA FAIXA IDADES', fontsize= 10, color='#04052E' )
plt.ylabel( 'SCORE - CLIENTES',  fontsize= 10, color='#04052E' )

for i in ax.patches:
      ax.annotate(format( i.get_height(), '.3f')+"",
                                 (i.get_x() + i.get_width() / 2, 
                                  i.get_height() +1 ),
                                  ha='center',
                                  va='baseline',
                                  fontsize= 13,
                                  color='#04052E',
                                  fontweight='ultralight',
                                  xytext=( 0, 1 ),
                                  rotation= 0.0,
                                  textcoords='offset pixels' ), 
plt.text( x= -1.7, 
         y= 40,
         s='$\\bf{NOTAÇÃO}$\n'
         'A maior média\n'
         'está concentrada\n'
         'entre os indivíduos com \n'
         'idade entre 35 e 65 .',
         verticalalignment="top",
         fontsize=12,
         color='#00072D' ); 

plt.xticks( color='#04052E', 
            fontsize=12, rotation= 0 )

plt.legend()
plt.grid( False )
plt.box( False )
plt.axhline(y = .5, xmin = 0.5, xmax = 0.9, color='#D90429')
plt.title( 'QUANTITATIVO POR FAIXA DE IDADE X SCORE MÉDIO', 
                        pad=25, fontsize=14, color='#04052E' )

plt.tight_layout()

# %%
# Agrupamento pela variável Escolaridade

agg_escol_score = df_raw.groupby( [ 'ESCOLARIDADE' ] ).mean()[ 'SCORE' ]
agg_escol_score.head()
# Out:
# ESCOLARIDADE
# Segundo Grau Completo   50.13
# Superior Completo       52.62
# Superior Cursando       52.50
# Name: SCORE, dtype: float64

# %%
# Conhecendo o quantitativo das ocorrências de "ESTADO_CIVIL" com Percentil

print( 'Python, imprima quantitativo por escolaridade em percentual\n' )
df_raw[ 'ESCOLARIDADE' ].value_counts( normalize=True ).map("{:.2%}".format)
# Out:
# Python, imprima quantitativo por escolaridade em percentual
# Superior Completo        36.48%
# Superior Cursando        33.04%
# Segundo Grau Completo    30.49%
# Name: ESCOLARIDADE, dtype: object

# %%
# Aplicação de gráfico customizado nova variável agrupada faixa escolaridade e Score

print( )
fig, ax = plt.subplots(figsize=( 15, 5 ) )
agg_escol_score.plot( kind='bar', color = [ '#00CECB' ] );
    
plt.xlabel( 'ESCALA ESCOLARIDADE', fontsize= 10, color='#00072D' )
plt.ylabel( 'SCORE - CLIENTES',  fontsize= 10, color='#00072D' )

for i in ax.patches:
      ax.annotate(format( i.get_height(), '.3f')+"",
                                 (i.get_x() + i.get_width() / 2, 
                                  i.get_height() +1),
                                  ha='center',
                                  va='baseline',
                                  fontsize= 13,
                                  color='#00072D',
                                  fontweight='ultralight',
                                  xytext=( 0, 1 ),
                                  rotation= 0.0,
                                  textcoords='offset pixels'), 

plt.text( x= -1.3, 
          y= 40,
          s='$\\bf{NOTAÇÃO}$\n'
          'A maior média\n'
          'está concentrada\n'
          'entre os indivíduos com \n'
          'superior completo.',
          verticalalignment="top",
          fontsize=13,
          color='#00072D' );

plt.xticks( color='#00072D',
            fontsize= 12, rotation= 0 )
plt.legend()
plt.grid( False )
plt.box( False )
plt.title( 'QUANTITATIVO POR FAIXA DE ESCOLARIDADE X SCORE', 
                        pad=25, fontsize=14, color='#00072D' )

plt.tight_layout()

# %%
# Agrupamento pela variável estado civil

agg_est_civil_score = df_raw.groupby( [ 'ESTADO_CIVIL' ] ).mean()[ 'SCORE' ]
agg_est_civil_score.head()
# Out:
# ESTADO_CIVIL
# Casado       57.33
# Divorciado   48.62
# Solteiro     37.69
# Viuvo        78.32
# Name: SCORE, dtype: float64

# %%
# Conhecendo o quantitativo das ocorrências de "ESTADO_CIVIL" com Percentil

print( 'Python, imprima quantitativo por estado civil em percentual\n' )
df_raw[ 'ESTADO_CIVIL' ].value_counts( normalize=True ).map("{:.2%}".format)
# Out:
# Python, imprima quantitativo por estado civil em percentual
# Casado        46.28%
# Divorciado    25.22%
# Solteiro      22.87%
# Viuvo          5.63%
# Name: ESTADO_CIVIL, dtype: object

# %%
# Aplicação de gráfico customizado nova variável agrupada faixa escolaridade e Score

print( )
fig, ax = plt.subplots(figsize=( 15, 5 ) )
agg_est_civil_score.plot( kind='bar', color = [ '#FF5400' ] );
    
plt.xlabel( 'ESTADO CIVIL', fontsize= 12, color='#03045E' )
plt.ylabel( 'SCORE - CLIENTES',  fontsize= 12, color='#03045E' )

for i in ax.patches:
      ax.annotate(format( i.get_height(), '.3f')+"",
                                 (i.get_x() + i.get_width() / 2, 
                                  i.get_height() +1),
                                  ha='center',
                                  va='baseline',
                                  fontsize= 13,
                                  color='#03045E',
                                  fontweight='ultralight',
                                  xytext=( 0, 1 ),
                                  rotation= 0.0,
                                  textcoords='offset pixels'), 
plt.text( x= -1.7, 
          y= 40,
          s='$\\bf{NOTAÇÃO}$\n'
          'A maior média\n'
          'está concentrada\n'
          'entre os indivíduos viúvos\n'
          'e casados.',
          verticalalignment="top",
          fontsize=13,
          color='#00072D' ); 

plt.xticks( color='#03045E', 
            fontsize=12, rotation= 0 )
plt.legend()
plt.grid( False )
plt.box( False )
plt.title( 'QUANTITATIVO POR ESTADO CIVIL X SCORE', 
                        pad=25, fontsize=14, color='#03045E' )

plt.tight_layout()

# %%
# Agrupamento pela variável estado civil

agg_empregado_score = df_raw.groupby( [ 'TRABALHANDO_ATUALMENTE' ] ).mean()[ 'SCORE' ]
agg_empregado_score.head()
# Out:
# TRABALHANDO_ATUALMENTE
# Não   59.97
# Sim   46.36
# Name: SCORE, dtype: float64

# %%
# Conhecendo o quantitativo das ocorrências de "emprego" com Percentil

print( 'Python, imprima quantitativo se está empregado ou não percentual\n' )
df_raw[ 'TRABALHANDO_ATUALMENTE' ].value_counts( normalize=True ).map("{:.2%}".format)
# Out:
# Python, imprima quantitativo se está empregado ou não percentual
# Sim    59.88%
# Não    40.12%
# Name: TRABALHANDO_ATUALMENTE, dtype: object

# %%
# Agrupamento pela variável estado civil

agg_casaprop_score = df_raw.groupby( [ 'CASA_PROPRIA' ] ).mean()[ 'SCORE' ]
agg_casaprop_score.head()
# Out:
# CASA_PROPRIA
# Não   48.89
# Sim   55.27
# Name: SCORE, dtype: float64

# %%
# Conhecendo o quantitativo das ocorrências de "casa própria" com Percentil

print( 'Python, imprima quantitativo de casa própria percentual\n' )
df_raw[ 'CASA_PROPRIA' ].value_counts( normalize=True ).map("{:.2%}".format)
# Out:
# Python, imprima quantitativo de casa própria percentual
# Não    54.09%
# Sim    45.91%
# Name: CASA_PROPRIA, dtype: object

# %%
# Agrupamento pela variável outra renda se sim ou não

agg_casaprop_score = df_raw.groupby( [ 'OUTRA_RENDA_VALOR' ] ).mean()[ 'SCORE' ]
agg_casaprop_score.head()
# Out:
# OUTRA_RENDA_VALOR
# 0      47.13
# 2400   50.67
# 3000   45.17
# 3200   94.67
# 4000   89.17
# Name: SCORE, dtype: float64

# %%
# Conhecendo o quantitativo das ocorrências de "outra renda" com Percentil

print( 'Python, imprima quantitativo outra renda percentual\n' )
df_raw[ 'OUTRA_RENDA_VALOR' ].value_counts( normalize=True ).map("{:.2%}".format)
# Out:
# Python, imprima quantitativo outra renda percentual
# 0       79.12%
# 3000     5.81%
# 3200     5.26%
# 4000     5.08%
# 2400     4.72%
# Name: OUTRA_RENDA_VALOR, dtype: object

# %% [markdown]
# ---
# ### Pré-processamento para aplicação de ( IA ) `Machine Learning`
#
#   - Checar as variáveis categóricas para processamento com LabelEncoder.
#   - Aplicação de Label Encoder para tranformar o que é categórica em 0, 1, 2...
#   - Ele pega as categorias por exemplo "sim e não" e tranforma em ( 0 e 1 ), e assim sucessivamente com todas as var. categoricas.
#   - Cópia dos dados, cópia de segurança e checagem de dados ausentes
#   - Separação da variável criada emprestimo.

# %%
# For para relacinar as variáveis categóricas

var_categoricas = [ ] 

print( f'\nPrint variáveis categóricas:\n' )

for i in df_raw.columns[ 0:48 ].tolist():
           if df_raw.dtypes[ i ] == ( 'object' ) or df_raw.dtypes[i] == ( 'category' ):
              print( i, ':', df_raw.dtypes[ i ] )
              var_categoricas.append( i )
# Out:
# Print variáveis categóricas:
#
# UF : object
# ESCOLARIDADE : object
# ESTADO_CIVIL : object
# CASA_PROPRIA : object
# OUTRA_RENDA : object
# TRABALHANDO_ATUALMENTE : object
# FAIXA_ETARIA : category

# %% [markdown]
# ### Aplicarei algumas técnicas necessárias para o bom andamento dos trabalhos de predição
#    - Abrindo a base, passando para outro objeto "Python", criando as leituras e tratamenos em bloco.
#    - Farei cópia dos dados por precaucão, seguindo política de boas práticas.
#    - Farei "encoder" em todas às variáveis string-object, mas antes separo a base em duas, uma terá a coluna criada emprestimos e outra base não.

# %%
# Criando outro DataFrame, objeto Python

df_prep = df_raw.copy()

df_prep.head(3).iloc[ :, 13:20 ]
# Out:
#    ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  SCORE FAIXA_ETARIA
# 1         4800.00          1                50000  18.00     De 20-25
# 2         2200.00          2                30000  23.00     De 20-25
# 3         3900.00          0                    0  28.67     De 25-35

# %%
# Chamando a base, passando para outro objeto "Python" 
# Farei cópia dos dados por precaucão, seguindo política de boas práticas.
# Farei "encoder" em todas às variáveis string, object.  


# Aplicação do método "LabelEncoder" para transformar as variáveis categóricas, passando para variável "lb_score"

lb_score = LabelEncoder()

df_prep[ 'UF' ]                     = lb_score.fit_transform(df_prep[ 'UF' ] )
df_prep[ 'OUTRA_RENDA' ]            = lb_score.fit_transform(df_prep[ 'OUTRA_RENDA' ] )
df_prep[ 'FAIXA_ETARIA' ]           = lb_score.fit_transform(df_prep[ 'FAIXA_ETARIA' ] )
df_prep[ 'ESTADO_CIVIL' ]           = lb_score.fit_transform(df_prep[ 'ESTADO_CIVIL' ] )
df_prep[ 'CASA_PROPRIA' ]           = lb_score.fit_transform(df_prep[ 'CASA_PROPRIA' ] )
df_prep[ 'ESCOLARIDADE' ]           = lb_score.fit_transform(df_prep[ 'ESCOLARIDADE' ] )
df_prep[ 'TRABALHANDO_ATUALMENTE' ] = lb_score.fit_transform(df_prep[ 'TRABALHANDO_ATUALMENTE' ] )

# Aplicação de Dropna para garantir que não haja dados ausentes de espécie alguma. Esses dados entrarão em produção de Machine Learning
# Inplace True para gravar na base origem

df_prep.dropna( inplace = True )

# %%
# lendo três linnhas da base com "LabelEncoder" aplicado para visualizar dás transformações e check do exemplo acima "ESCOLARIDADE".

df_prep.head( 3 )
# Out:
#    CODIGO_CLIENTE  UF  IDADE  ESCOLARIDADE  ESTADO_CIVIL  ...  ULTIMO_SALARIO  \
# 1               2   0     23             1             2  ...         4800.00
# 2               3   3     25             0             0  ...         2200.00
# 3               4   1     27             2             0  ...         3900.00
#
#    QT_CARROS  VALOR_TABELA_CARROS  SCORE  FAIXA_ETARIA
# 1          1                50000  18.00             0
# 2          2                30000  23.00             0
# 3          0                    0  28.67             1
#
# [3 rows x 18 columns]

# %% [markdown]
# ### Slice - extração da variável alvo ( Score )  com extração das Preditoras
#   - Aplicarei um slice com `iloc` para dar início dos trabalhos de predição, com aplicaçao de Marchine Learning
#   - Checagem com "df_pred.info" da ordem dás varáveis, principalemte a variável Alvo ( Target - Score )
#   - A var alvo está na posição "15", sendo reservado para ela a posição "16".
#   - df_pred.info()

# %%
# Aplicando o Slice com iloc, essa é uma dás formas de fazer slice, usarei variações de métodos, passando a target para "varviavel_target"
# Explicando o slice com Método iloc. Até ":" significa que eu quero todas às linhas, depois da "," quero só a coluna alvo "SCORE" posição reservada "16".

variavel_target = df_prep.iloc[ :, 16:17 ]

variavel_target.head( 3 )
# Out:
#    SCORE
# 1  18.00
# 2  23.00
# 3  28.67

# %%
# Extração das variáveis preditoras - Agora passo para dentro da var predicao todas menos a target SCORE.

predicao = df_prep.copy()

del predicao[ 'SCORE' ]

predicao.head( 3 )
# Out:
#    CODIGO_CLIENTE  UF  IDADE  ESCOLARIDADE  ESTADO_CIVIL  ...  \
# 1               2   0     23             1             2  ...
# 2               3   3     25             0             0  ...
# 3               4   1     27             2             0  ...
#
#    TRABALHANDO_ATUALMENTE  ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  \
# 1                       0         4800.00          1                50000
# 2                       1         2200.00          2                30000
# 3                       0         3900.00          0                    0
#
#    FAIXA_ETARIA
# 1             0
# 2             0
# 3             1
#
# [3 rows x 17 columns]

# %% [markdown]
# ### Separação dos dados para implementação de Machine Learning - IA
#   - Separação dos dado em ( X, e y ) para entrar o primeiro modelo em produção.
#   - Normalização dos dados MinmaxScaler para padronização e aplicação nos dados de treino e testes.

# %%
# Aplicação dos dados de treino e testes, com ( "train_X e test_y", predicao e variavel_target )

train_X, test_X, train_y, test_y = train_test_split( predicao, variavel_target, test_size = 0.3, random_state = 40 )

# %%
# Normalização e padronização dos dados

pdscaler = MinMaxScaler()

train_X_normalizado = pdscaler.fit_transform( train_X )
test_X_normalizado  = pdscaler.transform( test_X )

# %% [markdown]
# ### Modelo entrando em produção com dados de treinos e testes para predições

# %%
# Modelprediction 

model_pred = LinearRegression( normalize= True, fit_intercept = True ) 
model_pred = model_pred.fit( train_X_normalizado, train_y ) 

# Gerando a métrica r2_score para ver qual acurácio o modelo construiu.

print( f'\nResultado do modelo Regressão Linear:\n' )

result_r2 = r2_score( test_y, model_pred.fit( train_X_normalizado, train_y ).predict( test_X_normalizado ) )

print( f'Resultado r2_score:\f', result_r2 )
# Out:
# Resultado do modelo Regressão Linear:
#
# Resultado r2_score: 0.7914189275705912

# %% [markdown]
# ---
# ### Aplicação de **Machine Learning** para liberação de empréstimos pessoais
#   - Importando a base para aplicação de um novo modelo de Machine Learning - IA
#   - Pré-processamento: `LabelEncoder` e separação da variável **Target**: ( Alvo )
#   - Aplicarei para esse processo a Random Forest.
#   - Separação dos dados de treino testes ( train_X, test_X, train_y, teste_y )
# ### Importando a base original dados de crédito
# ---

# %%
# Importando a base e fazendo a leitura da coluna - 10 até coluna 17 

file_path = ( './img/dados_credito.xlsx' )
df_cred   = pd.read_excel( file_path ).copy()

df_cred.head( 3 ).iloc[ :, 10:18 ]
# Out:
#    TEMPO_ULTIMO_EMPREGO_MESES TRABALHANDO_ATUALMENTE  ULTIMO_SALARIO  \
# 0                           8                    Sim            1800
# 1                           9                    Não            4800
# 2                          18                    Sim            2200
#
#    QT_CARROS  VALOR_TABELA_CARROS  SCORE_CREDITO EMPRESTIMO
# 0          0                    0          56.00        SIM
# 1          1                50000          18.00        NAO
# 2          2                30000          45.00        SIM

# %%
# Aplicação do método "LabelEncoder" e dropna só para garantir que não terei dados ausentes criados com "L.E".

lb_cred = LabelEncoder()

df_cred[ 'TRABALHANDO_ATUALMENTE' ] = lb_cred.fit_transform(df_cred['TRABALHANDO_ATUALMENTE' ] )
df_cred[ 'ESTADO_CIVIL' ]           = lb_cred.fit_transform(df_cred[ 'ESTADO_CIVIL' ] )
df_cred[ 'CASA_PROPRIA' ]           = lb_cred.fit_transform(df_cred[ 'CASA_PROPRIA' ] )
df_cred[ 'ESCOLARIDADE' ]           = lb_cred.fit_transform(df_cred[ 'ESCOLARIDADE' ] )
df_cred[ 'EMPRESTIMO' ]             = lb_cred.fit_transform(df_cred[ 'EMPRESTIMO' ] )
df_cred[ 'UF' ]                     = lb_cred.fit_transform(df_cred[ 'UF' ] )

# Removendo a coluna ID Cliente

df_cred.drop( [ 'CODIGO_CLIENTE' ], axis=1, inplace=True )

# Remove valores missing eventualmente gerados

df_cred.dropna(inplace = True)

df_cred.head( 3 )
# Out:
#    UF  IDADE  ESCOLARIDADE  ESTADO_CIVIL  QT_FILHOS  ...  ULTIMO_SALARIO  \
# 0   4     19             2             2          0  ...            1800
# 1   0     23             1             2          1  ...            4800
# 2   3     25             0             0          0  ...            2200
#
#    QT_CARROS  VALOR_TABELA_CARROS  SCORE_CREDITO  EMPRESTIMO
# 0          0                    0          56.00           1
# 1          1                50000          18.00           0
# 2          2                30000          45.00           1
#
# [3 rows x 16 columns]

# %%
# Separação, slice da variável alvo ( Target ) Emprestimo.

target_cred = df_cred.iloc[ :, 15 ]
target_cred.head( 5 ).reset_index()
# Out:
#    index  EMPRESTIMO
# 0      0           1
# 1      1           0
# 2      2           1
# 3      3           0
# 4      4           1

# %%
# Extração das variáveis preditoras, passo para dentro da variável predicao todas, menos a target SCORE.

predict = df_cred.copy()

del predict[ 'EMPRESTIMO' ] 

predict.head( 3 )
# Out:
#    UF  IDADE  ESCOLARIDADE  ESTADO_CIVIL  QT_FILHOS  ...  \
# 0   4     19             2             2          0  ...
# 1   0     23             1             2          1  ...
# 2   3     25             0             0          0  ...
#
#    TRABALHANDO_ATUALMENTE  ULTIMO_SALARIO  QT_CARROS  VALOR_TABELA_CARROS  \
# 0                       1            1800          0                    0
# 1                       0            4800          1                50000
# 2                       1            2200          2                30000
#
#    SCORE_CREDITO
# 0          56.00
# 1          18.00
# 2          45.00
#
# [3 rows x 15 columns]

# %%
# Separação dos dados para "train_test_split"

train_X, test_X, train_y, test_y = train_test_split( predict, target_cred, test_size = 0.3, random_state = 40 )

# %%
# Padronização das variáveis numéricas com Scaler fit.transform

scaler_c = MinMaxScaler() 

train_X_normalizado = scaler_c.fit_transform( train_X )
test_X_normalizado  = scaler_c.transform( test_X )

# %% [markdown]
# * Aplicar Random Forest, avaliar e treinar o modelo preditivo para emprestimos
# - Resumo dos parâmetros à serem consumidos pelo modelo - `format HTML`
#   - <p> n_estimators - número de árvores da floresta;<br>
# max_features - O número de features a serem considerados ao procurar a melhor divisão;<br>
# max_depth - profundidade máxima das árvores;<br>
# min_samples_split - Número mínimo de amostras necessárias para dividir um nó interno;<br>
# min_samples_leaf - O número mínimo de amostras necessárias para estar em um nó folha;<br>
# bootstrap - Se as amostras de autoinicialização serão usadas na construção de árvores. Se False, o conjunto de dados inteiro é usado para criar cada árvore<br>
# ___

# %%
# Aplicando o modelo "Random Forest", e gerando os parâmetros

clf = RandomForestClassifier( )

clf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Montagem e parâmetrização do grid de hiperparâmetros random forest - "árvore de descisão"

n_estimators      = np.array( [ 100, 150, 200, 250, 300 ] )
max_depth         = np.array( [ 10, 20 ] )
criterion         = np.array( [ 'gini', 'entropy' ] )
max_features      = np.array( ['sqrt', 'log2', None ] )
min_samples_split = np.array( [ 1, 2, 5 ] )
min_samples_leaf  = np.array( [ 1, 2, 3] )
bootstrap         = np.array( [ 'True','False' ] )

# Hiperparâmetros para rendom forest

grid_parametros   = dict( 
                           n_estimators = n_estimators,
                           max_depth = max_depth,
                           criterion = criterion,
                           max_features = max_features,
                           min_samples_split = min_samples_split,
                           min_samples_leaf = min_samples_leaf,
                           bootstrap = bootstrap 
                         )

# Aplicação do Modelo com Grid de Hiperpar.

clf = GridSearchCV( clf, grid_parametros, cv = 3, n_jobs = 8 )

# Treinamento do modelo com parâmetros acima.

inicio_time = time.time()
clf.fit( train_X_normalizado, train_y )
fim_time = time.time()

# Relatório de obtenção dos parâmetros de treinamento do modelo

treinamento_start = pd.DataFrame( clf.cv_results_ )

# Acurácia e desempenho do treinamento do modelo RF

print( f'Acurácia do modelo em treinamento\f: {clf.best_score_ :.2%}' )
print( "" )
print( f'Hiperparâmetros selecionados: { clf.best_params_}' )
print( "" )
print( 'Número de treinamentos realizados\f:', treinamento_start.shape[0] )
print( "" )
print( 'Tempo de treinamento do Modelo\f:', round( fim_time - inicio_time, 2 ) )
# Out:
# Acurácia do modelo em treinamento: 84.36%
#
# Hiperparâmetros selecionados: {'bootstrap': 'False', 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
#
# Número de treinamentos realizados: 1080
#
# Tempo de treinamento do Modelo: 346.08

# %% [markdown]
# * Abrindo a variável **trainamento_start** para ver como foram engenheirados e distribuídos os dados de treinamento com `RandomForest`

# %%
treinamento_start.head( 2 ).iloc[ :, 9:18 ]
# Out:
#   param_min_samples_split param_n_estimators  \
# 0                       1                100
# 1                       1                150
#
#                                               params  split0_test_score  \
# 0  {'bootstrap': 'True', 'criterion': 'gini', 'ma...                NaN
# 1  {'bootstrap': 'True', 'criterion': 'gini', 'ma...                NaN
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0                NaN                NaN              NaN             NaN
# 1                NaN                NaN              NaN             NaN
#
#    rank_test_score
# 0             1080
# 1              758

# %%
# Aplicando classificador com Random Forest para gerar métricas de desempenho dos modelos - cruzando ( X e y )

model_dt = RandomForestClassifier( n_estimators  = 300, criterion = 'entropy', max_depth = 20, max_features = None,
                              min_samples_leaf = 1, min_samples_split = 5, bootstrap = True )

# Construção do modelo

model_dt = model_dt.fit( train_X_normalizado, train_y )

# %%
# Simulação dos dados de teste para entender as métricas em train_X

scores_x = model_dt.score( train_X_normalizado, train_y ) * 100
print( '\nPercentual de acurácia do score em dados de treinamento:\f', ( scores_x ) )
# Out:
# Percentual de acurácia do score em dados de treinamento: 87.35714285714286

# %%
# Simulação dos dados de teste para entender as métricas em train_y

scores_y = model_dt.score( test_X_normalizado, test_y ) * 100
print( '\nPercentual de acurácia do score em dados de teste:\f', scores_y )
# Out:
# Percentual de acurácia do score em dados de teste: 82.16666666666667

# %% [markdown]
# ___
# * <span style='background-color:lightyellow'>Observando os percentís acima, tanto de treino quanto de teste, posso concluir que como a diferença não é tão significativa, são apenas 6 pontos, significa que os dados treinaram bem e não houve vazamento de dados - data leakege.
# * <span style='background-color:lightyellow'>Existem parâmetros que posso medir e saber quanto essa diferença é prejudícial para os dados.<span style>

# %%
# Exibindo a importancia de cada variavel no modelo preditivo

plt.rcParams["figure.figsize"] = [ 12.00, 6.00 ]
plt.rcParams["figure.autolayout"] = False

feat_importances = pd.Series( data=model_dt.feature_importances_, index=predict.columns )
feat_importances = feat_importances.sort_values( ascending = False )
sns.barplot( x=feat_importances, y=feat_importances.index, palette= [ '#00BBF9' ], orient='h');
plt.title( 'IMPORTÂNCIA DE CADA VARIÁVEL PARA O MODELO GERADO', 
                         pad=15, fontsize=12, color='#001427' )

plt.xticks( color='#001427', 
            fontsize=9, rotation= 0 )
plt.yticks( color='#001427', 
            fontsize=9, rotation= 0 )
plt.grid( False )
plt.box( False )

plt.tight_layout()

# %%
# Relatório das variáveis com maior importancia para a árvore RF.

print( f'\nRelatório dás features inportance Random Forest:\n\n', feat_importances )
# Out:
# Relatório dás features inportance Random Forest:
#
#  SCORE_CREDITO            0.35
# IDADE                    0.21
# QT_FILHOS                0.08
# ULTIMO_SALARIO           0.08
# UF                       0.08
#                          ...
# TRABALHANDO_ATUALMENTE   0.01
# QT_CARROS                0.01
# OUTRA_RENDA_VALOR        0.01
# CASA_PROPRIA             0.01
# QT_IMOVEIS               0.00
# Length: 15, dtype: float64

# %%
# Lista array das variáveis com percentual e sua importância para o modelo Random Forest ( Árvore de descisão )

feature_labels = np.array( [
                            'SCORE_CREDITO', 'IDADE', 'ULTIMO_SALARIO', 'UF', 'QT_FILHOS', 'TEMPO_ULTIMO_EMPREGO_MESES', 'ESTADO_CIVIL', 
                            'VALOR_TABELA_CARROS', 'ESCOLARIDADE', 'VL_IMOVEIS', 'TRABALHANDO_ATUALMENTE', 'QT_CARROS ', 'OUTRA_RENDA_VALOR',
                            'QT_IMOVEIS', 'CASA_PROPRIA' 
                            ] )

importance = model_dt.feature_importances_
feature_importance = importance.argsort()

print( 'Relatório das variáveis em percentil:\n' )
for index in feature_importance:
    print('{}-{:.2f}%:'.format( feature_labels[index], ( importance[index] * 100 )) )
# Out:
# Relatório das variáveis em percentil:
#
# ESTADO_CIVIL-0.48%:
# TEMPO_ULTIMO_EMPREGO_MESES-0.54%:
# ESCOLARIDADE-0.59%:
# OUTRA_RENDA_VALOR-0.64%:
# TRABALHANDO_ATUALMENTE-0.95%:
# VALOR_TABELA_CARROS-1.11%:
# ULTIMO_SALARIO-1.94%:
# QT_IMOVEIS-1.96%:
# UF-4.83%:
# VL_IMOVEIS-7.13%:
# SCORE_CREDITO-7.84%:
# QT_CARROS -7.89%:
# QT_FILHOS-8.02%:
# IDADE-21.32%:
# CASA_PROPRIA-34.77%:

# %% [markdown]
# ### Gerando dados da Árvore de descisão para visualizar a divisão e sub-divisão dos nós da árvore com <em>"entropy"

# %%
# Aplicação do modelo "DecisionTreeClassifier" com  max_depth e critério da arvore de decisão, GINI.

model_dt = DecisionTreeClassifier( max_depth = 4, criterion = 'entropy' )
model_dt.fit( train_X, train_y )
pred_y = model_dt.predict( test_X )

# %%
# Plotando a árvore do método ( entropy )

dot = export_graphviz( model_dt, filled=True, rounded=True, feature_names=test_X.columns, class_names=[ '0', '1' ] )
graph = pydotplus.graph_from_dot_data( dot )

print( "" )
print( 'ÁRVOR DE DESCISAO DO MODELO ENTROPY'.center( 160 ) )
print( "" )
Image( graph.create_png() )
# Out:
#                                                               ÁRVOR DE DESCISAO DO MODELO ENTROPY

# %% [markdown]
# ---
# ## <em>Indicadores Preditivos, Prescritivos e Cenarização<em>

# %% [markdown]
# ---
# ### Considerações sobre o projeto.
#   - Observando a árvore de descisão entropy e o relatório das variáveis que mais tem peso para as predições, podemos compreender como os modelos de classificação e fazem a construção hierarquica dos nós e folhas da árvore.
#   - Para gerar predições e cenarizações com maior riqueza e detalhamento, precisaria de mais dados subjetivos aos clientes e da empresa ofertante.
#   - Existem inúmeros fatores que usados para qualificar e construir score. Nesse trabalho o objetivo foi prever do total de clientes da base, quais performariam melhor com os modelos de <em>**Machine Learning**<em> e saber quais teriam aderência aos processos e qualficação, com base no <em>**`score`**<em> dos clientes.
#   - No mundo real, esses dados são cruzados com outras observações e informações do cliente, tanto para compras quanto empréstimos em instituições financeiras.
#   - Em tratando-se de <em>**Linhas de Crédito**<em>, as pontuações também responderam bem, mas exitem outras variáveis que serão computadas para determinar liberação, valor e etc.
#
# ### Modelo Implementado Random Forest ( Árvore de Descisão ).
# ___
#   - A acurácia do primeiro modelo em treinamento foi de: **84.46%**
#
#   - Os hiperparâmetros selecionados foram: **{'bootstrap': 'False', 'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}**
#
#   - O modelo teve um número de treinamentos realizados de: **1080**
#
#   - Tempo de treinamento do Modelo foi: **355.23**
#   - Objetivo foi alcançado.

# %% [markdown]
# ### Até o próximo projeto...
# ---

# %%
print( 
      '\nDBIAN TECHNOLOGY FOR BUSINESS\n',
      '\nClaudio Fabian Stychnicki',
      '\nGestor Comercial e Cientista de Dados\n',
      '\nPhone:\t (47) 9-92374737',
      '\nBlumenau - SC\n',
      '\nInformações complementares em meu linkedIn\n',
      '\nBest regards.'
      )
# Out:
# DBIAN TECHNOLOGY FOR BUSINESS
#
# Claudio Fabian Stychnicki
# Gestor Comercial e Cientista de Dados
#
# Phone:	 (47) 9-92374737
# Blumenau - SC
#
# Informações complementares em meu linkedIn
#
# Best regards.

# %% [markdown]
# ---
